# %%
import matplotlib.pyplot as plt
import numpy as np
import dark
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\users\keyan\appdata\local\programs\python\python36\lib\site-packages\matplotlib\style\core.py in use(style)
#     110             try:
# --> 111                 rc = rc_params_from_file(style, use_default_template=False)
#     112                 _apply_style(rc)
#
# c:\users\keyan\appdata\local\programs\python\python36\lib\site-packages\matplotlib\__init__.py in rc_params_from_file(fname, fail_on_error, use_default_template)
#    1065     """
# -> 1066     config_from_file = _rc_params_in_file(fname, fail_on_error)
#    1067
#
# c:\users\keyan\appdata\local\programs\python\python36\lib\site-packages\matplotlib\__init__.py in _rc_params_in_file(fname, fail_on_error)
#     981     rc_temp = {}
# --> 982     with _open_file_or_url(fname) as fd:
#     983         try:
#
# c:\users\keyan\appdata\local\programs\python\python36\lib\contextlib.py in __enter__(self)
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#
# c:\users\keyan\appdata\local\programs\python\python36\lib\site-packages\matplotlib\__init__.py in _open_file_or_url(fname)
#     966             encoding = "utf-8"
# --> 967         with open(fname, encoding=encoding) as f:
#     968             yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kplot/dark.mplstyle'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-989208ec9e24> in <module>()
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 import dark
#
# ~\Desktop\Science\Code\kplot\dark.py in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.style.use("kplot/dark.mplstyle")
#
# c:\users\keyan\appdata\local\programs\python\python36\lib\site-packages\matplotlib\style\core.py in use(style)
#     115                     "{!r} not found in the style library and input is not a "
#     116                     "valid URL or path; see `style.available` for list of "
# --> 117                     "available styles".format(style))
#     118
#     119
#
# OSError: 'kplot/dark.mplstyle' not found in the style library and input is not a valid URL or path; see `style.available` for list of available styles

# %%
x = np.linspace(0,2*np.pi,100)
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))
plt.plot(x,np.ones(100))
plt.plot(x,np.zeros(100))
plt.title("big test")
# Out:
# Text(0.5, 1.0, 'big test')
